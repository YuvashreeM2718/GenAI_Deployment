# %%
import uuid

# %%
NS = uuid.uuid4()
NS
# Out:
# UUID('179c61d7-a347-42db-afa8-3709fb25f3ee')

# %%
uuid.uuid5(NS, "page:2")
# Out:
# UUID('6a263348-aa1a-52e3-b186-7778e221a404')

# %%
import hashlib

# %%
fileName = "my_doc.txt"
data = b"Hello all ,"

# %%
hashlib.sha256(data).hexdigest()
# Out:
# '63ae7240e9f0d4a1f821b84c0513fc26488c1d33f728c2b74178db307a6b8903'

# %%
with open(fileName, "wb") as file:
    file.write(data)

# %%
fileName = "my_doc.txt"
data = b"I love data"

# %%
hashlib.sha256(data).hexdigest()
# Out:
# '036edf009a7a9481cc1355e44826e8a05c8f0c49b38b159cb294b4318f39e39d'

# %%
with open(fileName, "wb") as file:
    file.write(data)

# %%
import uuid

# %%
page = 1
doc = 23

# %%
uuid.uuid4()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 uuid.uuid4("BKJBKJD")
#
# TypeError: uuid4() takes 0 positional arguments but 1 was given

# %%
uuid.uuid4()
# Out:
# UUID('8e2917b0-c0df-4290-a5e0-ee1c4df31d53')

# %%
uuid.uuid4()
# Out:
# UUID('460f9bb5-7c99-4e84-bb49-45e2c9b10079')

# %%
uuid.uuid4()
# Out:
# UUID('d26fdde1-adfe-4f55-95f6-b512cc44f2fe')
